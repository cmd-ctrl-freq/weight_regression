# %%
# I might want to create virtualenvs for future notebooks. This one is using the system interpreter.
import sys
print(sys.executable)

# If you want to do that in the future:
# Out:
# /usr/bin/python3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install pandas
# !pip install scikit-learn scipy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/ctrl_freq/.local/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/ctrl_freq/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/lib/python3/dist-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ctrl_freq/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/ctrl_freq/.local/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (1.8.0)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (3.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ctrl_freq/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/lib/python3/dist-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: joblib>=1.1.1 in /home/ctrl_freq/.local/lib/python3.10/site-packages (from scikit-learn) (1.3.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('data.csv')
df = df.drop(columns=['Fasting'])
df
# Out:
#                DateTime  Weight (lbs)
# 0   2023-06-27 00:00:00         221.2
# 1   2023-06-28 00:00:00         221.9
# 2   2023-06-29 00:00:00         222.0
# 3   2023-06-30 00:00:00         220.1
# 4   2023-07-01 00:00:00         219.2
# 5   2023-07-02 00:00:00         219.6
# 6   2023-07-03 00:00:00         220.0
# 7   2023-07-04 00:00:00         220.2
# 8   2023-07-05 00:00:00         219.0
# 9   2023-07-06 00:00:00         220.2
# 10  2023-07-07 00:00:00         219.7
# 11  2023-07-09 18:28:00         219.0
# 12  2023-07-10 05:04:00         219.6

# %%
# Step 3: Convert "DateTime" column to datetime objects
df['DateTime'] = pd.to_datetime(df['DateTime'])

# Step 4: Prepare the input features (X) and the target variable (y)
X = df['DateTime'].astype(int).values.reshape(-1, 1)
y = df['Weight (lbs)'].values.reshape(-1, 1)

# %%
# Step 5: Create a LinearRegression model
model = LinearRegression()

# %%
# Step 6: Fit the model to the data
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Step 8: Visualize the linear regression line and the data points
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.xlabel('DateTime')
plt.ylabel('Weight (lbs)')
plt.title('Linear Regression')
plt.show()
